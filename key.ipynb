# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# import torch
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression

# %%
linear_data = pd.read_csv('data_linear.csv')

# %%
linear_data.columns = ['dien tich','gia']

# %%
linear_data.head()
# Out:
#    dien tich      gia
# 0    30.0000  448.524
# 1    32.4138  509.248
# 2    34.8276  535.104
# 3    37.2414  551.432
# 4    39.6552  623.418

# %%
# .iloc <=> Extract Data from DataFrame to Series
# values <=> Convert data from Series to 1D Numpy array
# reshape(-1,1) <=> Convert 1D Numpy Array to 2D numpy array, 1: number of column, -1: number of row (automatic calculate from number of elements)
X_linear = linear_data.iloc[:,0].values.reshape(-1,1)
y_linear = linear_data.iloc[:,1].values.reshape(-1,1)

# %%
# Normalize Data
X_linear=MinMaxScaler().fit_transform(X_linear)
y_linear=MinMaxScaler().fit_transform(y_linear)

# %%
#Visualize Scaled Data
plt.scatter(X_linear, y_linear)
plt.title('Linear Data Scaled')
plt.xlabel('mét vuông/100')
plt.ylabel('giá/100')
# Out:
# Text(0, 0.5, 'giá/100')

# %%
#Gợi ý:
#- Viết code tính hàm loss function
#- Viết code tính gradient descent
#- Viết code tính giá trị model dự đoán được
# ....
# Có thể tham khảo tại Assignment HW1 đã làm 

model = LinearRegression()
model.fit(X_linear,y_linear)
# Out:
# LinearRegression()

# %%
slope = model.coef_[0][0]
intercept = model.intercept_[0]

# %%
print(slope)
print(intercept)
# Out:
# 0.9981442391483439
# 0.0006978684393319501

# %%
new_data = np.array([[35],[45],[55]])
new_data = MinMaxScaler().transform(new_data)
predicted_data_new = model.predict(new_data)
predict_prices = MinMaxScaler().inverse_transform(predicted_data_new)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# c:\Users\DELL\OneDrive - Hanoi University of Science and Technology\Desktop\LinearRegression\key.ipynb Cell 11 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/DELL/OneDrive%20-%20Hanoi%20University%20of%20Science%20and%20Technology/Desktop/LinearRegression/key.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> new_data = np.array([[35],[45],[55]])
# ----> <a href='vscode-notebook-cell:/c%3A/Users/DELL/OneDrive%20-%20Hanoi%20University%20of%20Science%20and%20Technology/Desktop/LinearRegression/key.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a> new_data = MinMaxScaler().transform(new_data)
#       <a href='vscode-notebook-cell:/c%3A/Users/DELL/OneDrive%20-%20Hanoi%20University%20of%20Science%20and%20Technology/Desktop/LinearRegression/key.ipynb#X13sZmlsZQ%3D%3D?line=2'>3</a> predicted_data_new = model.predict(new_data)
#       <a href='vscode-notebook-cell:/c%3A/Users/DELL/OneDrive%20-%20Hanoi%20University%20of%20Science%20and%20Technology/Desktop/LinearRegression/key.ipynb#X13sZmlsZQ%3D%3D?line=3'>4</a> predict_prices = MinMaxScaler().inverse_transform(predicted_data_new)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return_tuple = (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\preprocessing\_data.py:512, in MinMaxScaler.transform(self, X)
#     499 def transform(self, X):
#     500     """Scale features of X according to feature_range.
#     501
#     502     Parameters
#    (...)
#     510         Transformed data.
#     511     """
# --> 512     check_is_fitted(self)
#     514     X = self._validate_data(
#     515         X,
#     516         copy=self.copy,
#    (...)
#     519         reset=False,
#     520     )
#     522     X *= self.scale_
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:1462, in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1459     raise TypeError("%s is not an estimator instance." % (estimator))
#    1461 if not _is_fitted(estimator, attributes, all_or_any):
# -> 1462     raise NotFittedError(msg % {"name": type(estimator).__name__})
#
# NotFittedError: This MinMaxScaler instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
plt.scatter(X_linear, y_linear, label ='area and price')
plt.plot(X_linear, model.predict(X_linear),color ='red', label = 'Linear Regression')
plt.scatter(new_data, predict_prices,color ='green',marker ='x',label ='predict new data')
plt.xlabel('Area')
plt.ylabel('Prices')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\DELL\OneDrive - Hanoi University of Science and Technology\Desktop\LinearRegression\key.ipynb Cell 12 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/DELL/OneDrive%20-%20Hanoi%20University%20of%20Science%20and%20Technology/Desktop/LinearRegression/key.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> plt.scatter(X_linear, y_linear, label ='area and price')
#       <a href='vscode-notebook-cell:/c%3A/Users/DELL/OneDrive%20-%20Hanoi%20University%20of%20Science%20and%20Technology/Desktop/LinearRegression/key.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a> plt.plot(X_linear, model.predict(X_linear),color ='red', label = 'Linear Regression')
# ----> <a href='vscode-notebook-cell:/c%3A/Users/DELL/OneDrive%20-%20Hanoi%20University%20of%20Science%20and%20Technology/Desktop/LinearRegression/key.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a> plt.scatter(new_data, predict_prices,color ='green',marker ='x',label ='predict new data')
#       <a href='vscode-notebook-cell:/c%3A/Users/DELL/OneDrive%20-%20Hanoi%20University%20of%20Science%20and%20Technology/Desktop/LinearRegression/key.ipynb#X14sZmlsZQ%3D%3D?line=3'>4</a> plt.xlabel('Area')
#       <a href='vscode-notebook-cell:/c%3A/Users/DELL/OneDrive%20-%20Hanoi%20University%20of%20Science%20and%20Technology/Desktop/LinearRegression/key.ipynb#X14sZmlsZQ%3D%3D?line=4'>5</a> plt.ylabel('Prices')
#
# NameError: name 'new_data' is not defined
